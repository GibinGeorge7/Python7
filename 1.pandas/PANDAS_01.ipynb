# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.json',
#  'PANDAS_00.ipynb',
#  'PANDAS_01.ipynb',
#  'sup.xlsx',
#  'sup1.json',
#  'supermarkets.xlsx']

# %%
import pandas
df1=pandas.read_excel("sup.xlsx",sheet_name=0)
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
#find num of rows and columns in existing data frame
# 6 rows &&  7 columns
df1.shape
# Out:
# (6, 7)

# %%
#ADD Columns to pandas dataframe ( IN-PLACE operation)
df1["Continent"]=df1.shape[0]*["North America"]
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees      Continent
# 0          Madeira                    8  North America
# 1      Bready Shop                   15  North America
# 2      Super River                   25  North America
# 3       Ben's Shop                   10  North America
# 4          Sanchez                   12  North America
# 5       Richvalley                   20  North America

# %%
df1.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
#ADD ROWS to pandas dataframe ( IN-PLACE operation)

# tranposes data frame ( rows becomes comuns)
df2=df1.T
df2
# Out:
#                                  0               1                 2  \
# ID                               1               2                 3
# Address               3666 21st St  735 Dolores St       332 Hill St
# City                 San Francisco   San Francisco     San Francisco
# State                     CA 94114        CA 94119  California 94114
# Country                        USA             USA               USA
# Supermarket Name           Madeira     Bready Shop       Super River
# Number of Employees              8              15                25
# Continent            North America   North America     North America
#
#                                  3                4                5
# ID                               4                5                6
# Address               3995 23rd St  1056 Sanchez St  551 Alvarado St
# City                 San Francisco    San Francisco    San Francisco
# State                     CA 94114       California         CA 94114
# ...

# %%
#ADD ROWS to pandas dataframe ( IN-PLACE operation)
df2["6"]=[7,"My address","my city","my state","my country","super Name",7,"NA"]
df2
# Out:
#                                  0               1                 2  \
# ID                               1               2                 3
# Address               3666 21st St  735 Dolores St       332 Hill St
# City                 San Francisco   San Francisco     San Francisco
# State                     CA 94114        CA 94119  California 94114
# Country                        USA             USA               USA
# Supermarket Name           Madeira     Bready Shop       Super River
# Number of Employees              8              15                25
# Continent            North America   North America     North America
#
#                                  3                4                5  \
# ID                               4                5                6
# Address               3995 23rd St  1056 Sanchez St  551 Alvarado St
# City                 San Francisco    San Francisco    San Francisco
# ...

# %%
#ADD ROWS to pandas dataframe ( IN-PLACE operation)
df1=df2.T
df1
# Out:
#   ID          Address           City             State     Country  \
# 0  1     3666 21st St  San Francisco          CA 94114         USA
# 1  2   735 Dolores St  San Francisco          CA 94119         USA
# 2  3      332 Hill St  San Francisco  California 94114         USA
# 3  4     3995 23rd St  San Francisco          CA 94114         USA
# 4  5  1056 Sanchez St  San Francisco        California         USA
# 5  6  551 Alvarado St  San Francisco          CA 94114         USA
# 6  7       My address        my city          my state  my country
#
#   Supermarket Name Number of Employees      Continent
# 0          Madeira                   8  North America
# 1      Bready Shop                  15  North America
# 2      Super River                  25  North America
# 3       Ben's Shop                  10  North America
# 4          Sanchez                  12  North America
# 5       Richvalley                  20  North America
# ...
